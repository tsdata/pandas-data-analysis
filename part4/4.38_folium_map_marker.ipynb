# %%
# 라이브러리 불러오기
import pandas as pd
import folium

# 대학교 리스트를 데이터프레임 변환
df = pd.read_excel('./data/서울지역_대학교_위치.xlsx', index_col=0)

# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], tiles="Cartodb Positron", 
                       zoom_start=12)

# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.index, df['위도'], df['경도']):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)

# 지도 객체 확인하기 
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5e8982588f810b91e1b9d27cd7edb6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5e8982588f810b91e1b9d27cd7edb6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5e8982588f810b91e1b9d27cd7edb6f = L.map(
#                 &quot;map_d5e8982588f810b91e1b9d27cd7edb6f&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de2564a957550617030157567ba8608f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_de2564a957550617030157567ba8608f.addTo(map_d5e8982588f810b91e1b9d27cd7edb6f);
#
#
#             var marker_6491da98584b72f7a3cde04ac27e5c32 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_d5e8982588f810b91e1b9d27cd7edb6f);
#
#
#         var popup_40d5c436bbf29ee32ce8800b6a7ab66d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6dc6d42f6b0c02425bf0f1e846273848 = $(`&lt;div id=&quot;html_6dc6d42f6b0c02425bf0f1e846273848&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_40d5c436bbf29ee32ce8800b6a7ab66d.setContent(html_6dc6d42f6b0c02425bf0f1e846273848);
#
#
#
#         marker_6491da98584b72f7a3cde04ac27e5c32.bindPopup(popup_40d5c436bbf29ee32ce8800b6a7ab66d)
#         ;
#
#
#
#
#             var marker_6d96bd81b460579059e12dc5a3972273 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_d5e8982588f810b91e1b9d27cd7edb6f);
#
#
#         var popup_620872cc50c269ba91837833cb8598f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b158c1807b1e41554f347d059e9b289d = $(`&lt;div id=&quot;html_b158c1807b1e41554f347d059e9b289d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_620872cc50c269ba91837833cb8598f5.setContent(html_b158c1807b1e41554f347d059e9b289d);
#
#
#
#         marker_6d96bd81b460579059e12dc5a3972273.bindPopup(popup_620872cc50c269ba91837833cb8598f5)
#         ;
#
#
#
#
#             var marker_4b54ea6e5bc831d9d32bfb8c5d319b73 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_d5e8982588f810b91e1b9d27cd7edb6f);
#
#
#         var popup_287262ac9d11aa430c0754b1be7a056d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37dc48c9a393c7168f5c1b766d3800c9 = $(`&lt;div id=&quot;html_37dc48c9a393c7168f5c1b766d3800c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_287262ac9d11aa430c0754b1be7a056d.setContent(html_37dc48c9a393c7168f5c1b766d3800c9);
#
#
#
#         marker_4b54ea6e5bc831d9d32bfb8c5d319b73.bindPopup(popup_287262ac9d11aa430c0754b1be7a056d)
#         ;
#
#
#
#
#             var marker_19ed7ad6f35c980ad13dd587392d6c42 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_d5e8982588f810b91e1b9d27cd7edb6f);
#
#
#         var popup_7c2fcead6bbb103e5fc0aa508b9cbf6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c046c57ef0ad369d4404df9311c9bd2 = $(`&lt;div id=&quot;html_9c046c57ef0ad369d4404df9311c9bd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_7c2fcead6bbb103e5fc0aa508b9cbf6e.setContent(html_9c046c57ef0ad369d4404df9311c9bd2);
#
#
#
#         marker_19ed7ad6f35c980ad13dd587392d6c42.bindPopup(popup_7c2fcead6bbb103e5fc0aa508b9cbf6e)
#         ;
#
#
#
#
#             var marker_d6dca84facc02f18810df6a06bec0187 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_d5e8982588f810b91e1b9d27cd7edb6f);
#
#
#         var popup_6e72b3729aac7662b538fa60158598d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90cad03eeed8ca92d05ce4db3e56428c = $(`&lt;div id=&quot;html_90cad03eeed8ca92d05ce4db3e56428c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_6e72b3729aac7662b538fa60158598d3.setContent(html_90cad03eeed8ca92d05ce4db3e56428c);
#
#
#
#         marker_d6dca84facc02f18810df6a06bec0187.bindPopup(popup_6e72b3729aac7662b538fa60158598d3)
#         ;
#
#
#
#
#             var marker_66004b5bce218be439ec5d2be39d1df9 = L.marker(
#                 [37.5407
